# %%
pip install pandoc
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pandoc: filename=pandoc-2.4-py3-none-any.whl size=34899 sha256=794ed311069b2408f663c3e3cf1bea6f2670225214547e6a1c382089c2757152
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\14\79\8c\5d7a023cc8df1aa0381c1739d69da18ae7f90c08b2dc9a1bf5
# Successfully built pandoc
# ...
#
#    ------------- -------------------------- 1/3 [plumbum]
#    ------------- -------------------------- 1/3 [plumbum]
#    ------------- -------------------------- 1/3 [plumbum]
#    ------------- -------------------------- 1/3 [plumbum]
#    ------------- -------------------------- 1/3 [plumbum]
# ...

# %%
import pdfkit
input_file = "input.html"
output_file = "output.pdf"
pdfkit.from_file(input_file, output_file)
