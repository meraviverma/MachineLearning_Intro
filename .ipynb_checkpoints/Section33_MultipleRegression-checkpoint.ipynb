# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib as plt
import seaborn as sns
import sklearn
sns.set()

# %%
data=pd.read_csv(r"E:\Udemy Course\the-data-science-course-complete-data-science-bootcamp\Section 32 Advanced Statistical Mathods Linear Regression With StatsModels\Multiplelinearregression.csv")
