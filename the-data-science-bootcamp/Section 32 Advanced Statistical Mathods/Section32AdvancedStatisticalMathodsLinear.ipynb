# %% [markdown]
# statsModels
# --------------
# a package built on top of Numpy and SciPy , which integrates with pandas. SM provides very good summaries

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib as plt
import seaborn as sns
import sklearn
sns.set()

# %%
data=pd.read_csv(r"D:\MachineLearning\MachineLearning_Intro\the-data-science-bootcamp\Section 32 Advanced Statistical Mathods\SimpleLinearRegression.csv")

# %%
import os
print(os.getcwd())
# Out:
# D:\MachineLearning\MachineLearning_Intro\the-data-science-bootcamp\Section 32 Advanced Statistical Mathods

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# SAT=Critical Reading + Mathematics + Writing
# GPA=Grade Point Average ( at graduation from unuversity)
# We will create a linear regression which predcits GPA based on the SAT score obtained
#
# Why would i predict GPA with SAT?
# 1. The SAT is considered one of the best elimitors of intellectual capacity and capability
# 2. Allmost all college across the USA are using the SAT as a proxy for admission
# 3. The SAT stood the test of time.

# %% [markdown]
# # Create your first regression

# %% [markdown]
# ### Define the dependent and independet variable

# %%
y=data['GPA']
x1=data['SAT']

# %% [markdown]
# ### Explore the data

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x1,y)
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
# Higher the SAT higher the GPA

# %%
x=sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Sat, 28 Mar 2026   Prob (F-statistic):           7.20e-11
# Time:                        10:23:24   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1,y)
yhat=0.0017*x1 + 0.275
fig=plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
plt.scatter(x1,y)
yhat=0.0017*x1 + 0
fig=plt.plot(x1,yhat,lw=4,c='green',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
plt.scatter(x1,y)
yhat=0*x1 + 0
fig=plt.plot(x1,yhat,lw=4,c='red',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()
